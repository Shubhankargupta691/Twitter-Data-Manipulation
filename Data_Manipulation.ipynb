# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
dataset = pd.read_csv('DataSet/Survey Monkey Output.csv')
dataset
# Out:
#      Respondent ID           Start Date             End Date  Email Address  \
# 0              NaN                  NaN                  NaN            NaN
# 1     5.379192e+09  2021-01-22 12:01:17  2021-01-22 12:40:34            NaN
# 2     2.658723e+09  2021-01-22 06:56:37  2021-01-22 07:34:10            NaN
# 3     4.044163e+09  2021-01-22 06:35:18  2021-01-22 06:47:32            NaN
# 4     5.535866e+09  2021-01-21 21:29:32  2021-01-21 21:40:24            NaN
# ..             ...                  ...                  ...            ...
# 194   7.940065e+09  2021-01-11 06:19:18  2021-01-11 06:32:59            NaN
# 195   5.157706e+09  2021-01-11 06:19:14  2021-01-11 06:33:29            NaN
# 196   9.920756e+09  2021-01-11 06:18:48  2021-01-11 06:27:27            NaN
# 197   6.638341e+09  2021-01-11 06:19:01  2021-01-11 06:33:06            NaN
# 198   8.114622e+09  2021-01-11 06:18:50  2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# 0           NaN        NaN            NaN
# 1           NaN        NaN            NaN
# 2           NaN        NaN            NaN
# 3           NaN        NaN            NaN
# 4           NaN        NaN            NaN
# ..          ...        ...            ...
# 194         NaN        NaN            NaN
# 195         NaN        NaN            NaN
# 196         NaN        NaN            NaN
# 197         NaN        NaN            NaN
# 198         NaN        NaN            NaN
#
#     Identify which division you work in.              Unnamed: 8  \
# 0                               Response  Other (please specify)
# 1                         Infrastructure                     NaN
# 2                                Finance                     NaN
# 3                         Infrastructure                     NaN
# 4                         Infrastructure                     NaN
# ..                                   ...                     ...
# 194                       Infrastructure                     NaN
# 195                              Finance                     NaN
# 196                      Port Operations                     NaN
# 197                       Infrastructure                     NaN
# 198               Information Technology                     NaN
#
#     Which of the following best describes your position level?  ...  \
# 0                                             Response          ...
# 1                                                Staff          ...
# 2                                                Staff          ...
# 3                                      Department Lead          ...
# 4                                              Manager          ...
# ..                                                 ...          ...
# 194                                    Department Lead          ...
# 195                                              Staff          ...
# 196                                              Staff          ...
# 197                                            Manager          ...
# 198                                              Staff          ...
#
#     Unnamed: 90 Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  \
# 0    Response 8  Response 9  Response 10  Response 11  Response 12
# 1           NaN    Answer 8     Answer 8     Answer 4          NaN
# 2           NaN    Answer 5          NaN          NaN     Answer 2
# 3           NaN         NaN     Answer 4     Answer 4     Answer 6
# 4      Answer 2    Answer 5     Answer 7          NaN     Answer 6
# ..          ...         ...          ...          ...          ...
# 194    Answer 1    Answer 1     Answer 3     Answer 6     Answer 6
# 195    Answer 5         NaN     Answer 5          NaN          NaN
# 196         NaN    Answer 7          NaN          NaN          NaN
# 197    Answer 2         NaN     Answer 3     Answer 5          NaN
# 198    Answer 3         NaN     Answer 7          NaN          NaN
#
#      Unnamed: 95  Unnamed: 96 Question 30 Unnamed: 98 Unnamed: 99
# 0    Response 13  Response 14  Response 1  Response 2  Response 3
# 1            NaN     Answer 5         NaN         NaN         NaN
# 2            NaN     Answer 5         NaN         NaN    Answer 1
# 3            NaN     Answer 6         NaN    Answer 1         NaN
# 4            NaN     Answer 7    Answer 7    Answer 1    Answer 6
# ..           ...          ...         ...         ...         ...
# 194     Answer 8          NaN         NaN         NaN    Answer 8
# 195     Answer 2          NaN         NaN         NaN    Answer 6
# 196          NaN          NaN         NaN    Answer 3         NaN
# 197     Answer 8     Answer 3    Answer 3         NaN         NaN
# 198          NaN          NaN    Answer 3         NaN         NaN
#
# [199 rows x 100 columns]

# %%
dataset_modified = dataset.copy()
dataset_modified
# Out:
#      Respondent ID           Start Date             End Date  Email Address  \
# 0              NaN                  NaN                  NaN            NaN
# 1     5.379192e+09  2021-01-22 12:01:17  2021-01-22 12:40:34            NaN
# 2     2.658723e+09  2021-01-22 06:56:37  2021-01-22 07:34:10            NaN
# 3     4.044163e+09  2021-01-22 06:35:18  2021-01-22 06:47:32            NaN
# 4     5.535866e+09  2021-01-21 21:29:32  2021-01-21 21:40:24            NaN
# ..             ...                  ...                  ...            ...
# 194   7.940065e+09  2021-01-11 06:19:18  2021-01-11 06:32:59            NaN
# 195   5.157706e+09  2021-01-11 06:19:14  2021-01-11 06:33:29            NaN
# 196   9.920756e+09  2021-01-11 06:18:48  2021-01-11 06:27:27            NaN
# 197   6.638341e+09  2021-01-11 06:19:01  2021-01-11 06:33:06            NaN
# 198   8.114622e+09  2021-01-11 06:18:50  2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# 0           NaN        NaN            NaN
# 1           NaN        NaN            NaN
# 2           NaN        NaN            NaN
# 3           NaN        NaN            NaN
# 4           NaN        NaN            NaN
# ..          ...        ...            ...
# 194         NaN        NaN            NaN
# 195         NaN        NaN            NaN
# 196         NaN        NaN            NaN
# 197         NaN        NaN            NaN
# 198         NaN        NaN            NaN
#
#     Identify which division you work in.              Unnamed: 8  \
# 0                               Response  Other (please specify)
# 1                         Infrastructure                     NaN
# 2                                Finance                     NaN
# 3                         Infrastructure                     NaN
# 4                         Infrastructure                     NaN
# ..                                   ...                     ...
# 194                       Infrastructure                     NaN
# 195                              Finance                     NaN
# 196                      Port Operations                     NaN
# 197                       Infrastructure                     NaN
# 198               Information Technology                     NaN
#
#     Which of the following best describes your position level?  ...  \
# 0                                             Response          ...
# 1                                                Staff          ...
# 2                                                Staff          ...
# 3                                      Department Lead          ...
# 4                                              Manager          ...
# ..                                                 ...          ...
# 194                                    Department Lead          ...
# 195                                              Staff          ...
# 196                                              Staff          ...
# 197                                            Manager          ...
# 198                                              Staff          ...
#
#     Unnamed: 90 Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  \
# 0    Response 8  Response 9  Response 10  Response 11  Response 12
# 1           NaN    Answer 8     Answer 8     Answer 4          NaN
# 2           NaN    Answer 5          NaN          NaN     Answer 2
# 3           NaN         NaN     Answer 4     Answer 4     Answer 6
# 4      Answer 2    Answer 5     Answer 7          NaN     Answer 6
# ..          ...         ...          ...          ...          ...
# 194    Answer 1    Answer 1     Answer 3     Answer 6     Answer 6
# 195    Answer 5         NaN     Answer 5          NaN          NaN
# 196         NaN    Answer 7          NaN          NaN          NaN
# 197    Answer 2         NaN     Answer 3     Answer 5          NaN
# 198    Answer 3         NaN     Answer 7          NaN          NaN
#
#      Unnamed: 95  Unnamed: 96 Question 30 Unnamed: 98 Unnamed: 99
# 0    Response 13  Response 14  Response 1  Response 2  Response 3
# 1            NaN     Answer 5         NaN         NaN         NaN
# 2            NaN     Answer 5         NaN         NaN    Answer 1
# 3            NaN     Answer 6         NaN    Answer 1         NaN
# 4            NaN     Answer 7    Answer 7    Answer 1    Answer 6
# ..           ...          ...         ...         ...         ...
# 194     Answer 8          NaN         NaN         NaN    Answer 8
# 195     Answer 2          NaN         NaN         NaN    Answer 6
# 196          NaN          NaN         NaN    Answer 3         NaN
# 197     Answer 8     Answer 3    Answer 3         NaN         NaN
# 198          NaN          NaN    Answer 3         NaN         NaN
#
# [199 rows x 100 columns]

# %%
columns_to_drop = ['Start Date', 'End Date', 'Email Address', 'First Name', 'Last Name', 'Custom Data 1']
columns_to_drop
# Out:
# ['Start Date',
#  'End Date',
#  'Email Address',
#  'First Name',
#  'Last Name',
#  'Custom Data 1']

# %%
dataset_modified = dataset_modified.drop(columns=columns_to_drop)
dataset_modified
# Out:
#      Respondent ID Identify which division you work in.  \
# 0              NaN                             Response
# 1     5.379192e+09                       Infrastructure
# 2     2.658723e+09                              Finance
# 3     4.044163e+09                       Infrastructure
# 4     5.535866e+09                       Infrastructure
# ..             ...                                  ...
# 194   7.940065e+09                       Infrastructure
# 195   5.157706e+09                              Finance
# 196   9.920756e+09                      Port Operations
# 197   6.638341e+09                       Infrastructure
# 198   8.114622e+09               Information Technology
#
#                  Unnamed: 8  \
# 0    Other (please specify)
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 194                     NaN
# 195                     NaN
# 196                     NaN
# 197                     NaN
# 198                     NaN
#
#     Which of the following best describes your position level?  \
# 0                                             Response
# 1                                                Staff
# 2                                                Staff
# 3                                      Department Lead
# 4                                              Manager
# ..                                                 ...
# 194                                    Department Lead
# 195                                              Staff
# 196                                              Staff
# 197                                            Manager
# 198                                              Staff
#
#         Which generation are you apart of?  \
# 0                                 Response
# 1    Generation X (born between 1965-1980)
# 2                                      NaN
# 3    Generation X (born between 1965-1980)
# 4      Millennial (born between 1981-2000)
# ..                                     ...
# 194   Baby Boomer (born between 1946-1964)
# 195    Millennial (born between 1981-2000)
# 196    Millennial (born between 1981-2000)
# 197    Millennial (born between 1981-2000)
# 198                   Prefer not to answer
#
#     Please select the gender in which you identify.  \
# 0                                          Response
# 1                                              Male
# 2                                               NaN
# 3                                              Male
# 4                                        Non-Binary
# ..                                              ...
# 194                                            Male
# 195                                          Female
# 196                                          Female
# 197                                          Female
# 198                                            Male
#
#     Which duration range best aligns with your tenure at your company?  \
# 0                                             Response
# 1                                            0-2 years
# 2                                            10+ years
# 3                                            3-5 years
# 4                                           5-10 years
# ..                                                 ...
# 194                                          10+ years
# 195                                         5-10 years
# 196                                          3-5 years
# 197                                          3-5 years
# 198                                         5-10 years
#
#     Which of the following best describes your employment type? Question 1  \
# 0                                             Response            Response
# 1                                   Full time Employee                 NaN
# 2                                   Full time Employee            Answer 4
# 3                                   Full time Employee            Answer 5
# 4                                   Full time Employee            Answer 1
# ..                                                 ...                 ...
# 194                                 Full time Employee            Answer 3
# 195                                 Full time Employee                 NaN
# 196                                 Full time Employee                 NaN
# 197                                 Full time Employee                 NaN
# 198                                 Full time Employee                 NaN
#
#     Question 2  ... Unnamed: 90 Unnamed: 91  Unnamed: 92  Unnamed: 93  \
# 0     Response  ...  Response 8  Response 9  Response 10  Response 11
# 1     Answer 6  ...         NaN    Answer 8     Answer 8     Answer 4
# 2     Answer 2  ...         NaN    Answer 5          NaN          NaN
# 3     Answer 7  ...         NaN         NaN     Answer 4     Answer 4
# 4     Answer 1  ...    Answer 2    Answer 5     Answer 7          NaN
# ..         ...  ...         ...         ...          ...          ...
# 194        NaN  ...    Answer 1    Answer 1     Answer 3     Answer 6
# 195        NaN  ...    Answer 5         NaN     Answer 5          NaN
# 196   Answer 7  ...         NaN    Answer 7          NaN          NaN
# 197        NaN  ...    Answer 2         NaN     Answer 3     Answer 5
# 198   Answer 1  ...    Answer 3         NaN     Answer 7          NaN
#
#      Unnamed: 94  Unnamed: 95  Unnamed: 96 Question 30 Unnamed: 98 Unnamed: 99
# 0    Response 12  Response 13  Response 14  Response 1  Response 2  Response 3
# 1            NaN          NaN     Answer 5         NaN         NaN         NaN
# 2       Answer 2          NaN     Answer 5         NaN         NaN    Answer 1
# 3       Answer 6          NaN     Answer 6         NaN    Answer 1         NaN
# 4       Answer 6          NaN     Answer 7    Answer 7    Answer 1    Answer 6
# ..           ...          ...          ...         ...         ...         ...
# 194     Answer 6     Answer 8          NaN         NaN         NaN    Answer 8
# 195          NaN     Answer 2          NaN         NaN         NaN    Answer 6
# 196          NaN          NaN          NaN         NaN    Answer 3         NaN
# 197          NaN     Answer 8     Answer 3    Answer 3         NaN         NaN
# 198          NaN          NaN          NaN    Answer 3         NaN         NaN
#
# [199 rows x 94 columns]

# %%
id_vars = list(dataset_modified.columns)[ : 8]
value_vars = list(dataset_modified.columns)[8 : ]
# value_vars

# %%
dataset_melted = dataset_modified.melt(id_vars=id_vars, value_vars = value_vars, var_name="Question + Subquestion", value_name="Answer")
dataset_melted
# Out:
#        Respondent ID Identify which division you work in.  \
# 0                NaN                             Response
# 1       5.379192e+09                       Infrastructure
# 2       2.658723e+09                              Finance
# 3       4.044163e+09                       Infrastructure
# 4       5.535866e+09                       Infrastructure
# ...              ...                                  ...
# 17109   7.940065e+09                       Infrastructure
# 17110   5.157706e+09                              Finance
# 17111   9.920756e+09                      Port Operations
# 17112   6.638341e+09                       Infrastructure
# 17113   8.114622e+09               Information Technology
#
#                    Unnamed: 8  \
# 0      Other (please specify)
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 17109                     NaN
# 17110                     NaN
# 17111                     NaN
# 17112                     NaN
# 17113                     NaN
#
#       Which of the following best describes your position level?  \
# 0                                               Response
# 1                                                  Staff
# 2                                                  Staff
# 3                                        Department Lead
# 4                                                Manager
# ...                                                  ...
# 17109                                    Department Lead
# 17110                                              Staff
# 17111                                              Staff
# 17112                                            Manager
# 17113                                              Staff
#
#           Which generation are you apart of?  \
# 0                                   Response
# 1      Generation X (born between 1965-1980)
# 2                                        NaN
# 3      Generation X (born between 1965-1980)
# 4        Millennial (born between 1981-2000)
# ...                                      ...
# 17109   Baby Boomer (born between 1946-1964)
# 17110    Millennial (born between 1981-2000)
# 17111    Millennial (born between 1981-2000)
# 17112    Millennial (born between 1981-2000)
# 17113                   Prefer not to answer
#
#       Please select the gender in which you identify.  \
# 0                                            Response
# 1                                                Male
# 2                                                 NaN
# 3                                                Male
# 4                                          Non-Binary
# ...                                               ...
# 17109                                            Male
# 17110                                          Female
# 17111                                          Female
# 17112                                          Female
# 17113                                            Male
#
#       Which duration range best aligns with your tenure at your company?  \
# 0                                               Response
# 1                                              0-2 years
# 2                                              10+ years
# 3                                              3-5 years
# 4                                             5-10 years
# ...                                                  ...
# 17109                                          10+ years
# 17110                                         5-10 years
# 17111                                          3-5 years
# 17112                                          3-5 years
# 17113                                         5-10 years
#
#       Which of the following best describes your employment type?  \
# 0                                               Response
# 1                                     Full time Employee
# 2                                     Full time Employee
# 3                                     Full time Employee
# 4                                     Full time Employee
# ...                                                  ...
# 17109                                 Full time Employee
# 17110                                 Full time Employee
# 17111                                 Full time Employee
# 17112                                 Full time Employee
# 17113                                 Full time Employee
#
#       Question + Subquestion    Answer
# 0                 Question 1  Response
# 1                 Question 1       NaN
# 2                 Question 1  Answer 4
# 3                 Question 1  Answer 5
# 4                 Question 1  Answer 1
# ...                      ...       ...
# 17109            Unnamed: 99  Answer 8
# 17110            Unnamed: 99  Answer 6
# 17111            Unnamed: 99       NaN
# 17112            Unnamed: 99       NaN
# 17113            Unnamed: 99       NaN
#
# [17114 rows x 10 columns]

# %%
w = pd.read_excel('DataSet/Survey Monkey Output Edited.xlsx')
w.head()
# Out:
#     Raw Question Raw Subquestion       Question Subquestion  \
# 0  Respondent ID             NaN  Respondent ID         NaN
# 1     Start Date             NaN     Start Date         NaN
# 2       End Date             NaN       End Date         NaN
# 3  Email Address             NaN  Email Address         NaN
# 4     First Name             NaN     First Name         NaN
#
#   Question + Subquestion
# 0          Respondent.ID
# 1             Start.Date
# 2               End.Date
# 3          Email.Address
# 4             First.Name

# %%
questions_import = pd.read_csv('DataSet/Questions.csv')
questions_import
# Out:
#      Raw Question Raw Subquestion       Question  Subquestion  \
# 0   Respondent ID             NaN  Respondent ID          NaN
# 1      Start Date             NaN     Start Date          NaN
# 2        End Date             NaN       End Date          NaN
# 3   Email Address             NaN  Email Address          NaN
# 4      First Name             NaN     First Name          NaN
# ..            ...             ...            ...          ...
# 95            NaN     Response 13    Question 29  Response 13
# 96            NaN     Response 14    Question 29  Response 14
# 97    Question 30      Response 1    Question 30   Response 1
# 98            NaN      Response 2    Question 30   Response 2
# 99            NaN      Response 3    Question 30   Response 3
#
#        Question + Subquestion
# 0               Respondent ID
# 1                  Start Date
# 2                    End Date
# 3               Email Address
# 4                  First Name
# ..                        ...
# 95  Question 29 - Response 13
# 96  Question 29 - Response 14
# 97   Question 30 - Response 1
# 98   Question 30 - Response 2
# 99   Question 30 - Response 3
#
# [100 rows x 5 columns]

# %%
questions = questions_import.copy()
questions.drop(columns=["Raw Question", "Raw Subquestion", "Subquestion"], inplace=True)

# %%
questions
# Out:
#          Question     Question + Subquestion
# 0   Respondent ID              Respondent ID
# 1      Start Date                 Start Date
# 2        End Date                   End Date
# 3   Email Address              Email Address
# 4      First Name                 First Name
# ..            ...                        ...
# 95    Question 29  Question 29 - Response 13
# 96    Question 29  Question 29 - Response 14
# 97    Question 30   Question 30 - Response 1
# 98    Question 30   Question 30 - Response 2
# 99    Question 30   Question 30 - Response 3
#
# [100 rows x 2 columns]

# %%
questions
# Out:
#          Question     Question + Subquestion
# 0   Respondent ID              Respondent ID
# 1      Start Date                 Start Date
# 2        End Date                   End Date
# 3   Email Address              Email Address
# 4      First Name                 First Name
# ..            ...                        ...
# 95    Question 29  Question 29 - Response 13
# 96    Question 29  Question 29 - Response 14
# 97    Question 30   Question 30 - Response 1
# 98    Question 30   Question 30 - Response 2
# 99    Question 30   Question 30 - Response 3
#
# [100 rows x 2 columns]

# %%
dataset_merged = pd.merge(left=dataset_melted, right=questions, how="left", left_on="Question + Subquestion", right_on="Question + Subquestion")
print("Original Data", len(dataset_melted))
print("Merged Data", len(dataset_merged))
dataset_merged
# Out:
# Original Data 17114
# Merged Data 17114
#        Respondent ID Identify which division you work in.  \
# 0                NaN                             Response
# 1       5.379192e+09                       Infrastructure
# 2       2.658723e+09                              Finance
# 3       4.044163e+09                       Infrastructure
# 4       5.535866e+09                       Infrastructure
# ...              ...                                  ...
# 17109   7.940065e+09                       Infrastructure
# 17110   5.157706e+09                              Finance
# 17111   9.920756e+09                      Port Operations
# 17112   6.638341e+09                       Infrastructure
# 17113   8.114622e+09               Information Technology
#
#                    Unnamed: 8  \
# 0      Other (please specify)
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 17109                     NaN
# 17110                     NaN
# 17111                     NaN
# 17112                     NaN
# 17113                     NaN
#
#       Which of the following best describes your position level?  \
# 0                                               Response
# 1                                                  Staff
# 2                                                  Staff
# 3                                        Department Lead
# 4                                                Manager
# ...                                                  ...
# 17109                                    Department Lead
# 17110                                              Staff
# 17111                                              Staff
# 17112                                            Manager
# 17113                                              Staff
#
#           Which generation are you apart of?  \
# 0                                   Response
# 1      Generation X (born between 1965-1980)
# 2                                        NaN
# 3      Generation X (born between 1965-1980)
# 4        Millennial (born between 1981-2000)
# ...                                      ...
# 17109   Baby Boomer (born between 1946-1964)
# 17110    Millennial (born between 1981-2000)
# 17111    Millennial (born between 1981-2000)
# 17112    Millennial (born between 1981-2000)
# 17113                   Prefer not to answer
#
#       Please select the gender in which you identify.  \
# 0                                            Response
# 1                                                Male
# 2                                                 NaN
# 3                                                Male
# 4                                          Non-Binary
# ...                                               ...
# 17109                                            Male
# 17110                                          Female
# 17111                                          Female
# 17112                                          Female
# 17113                                            Male
#
#       Which duration range best aligns with your tenure at your company?  \
# 0                                               Response
# 1                                              0-2 years
# 2                                              10+ years
# 3                                              3-5 years
# 4                                             5-10 years
# ...                                                  ...
# 17109                                          10+ years
# 17110                                         5-10 years
# 17111                                          3-5 years
# 17112                                          3-5 years
# 17113                                         5-10 years
#
#       Which of the following best describes your employment type?  \
# 0                                               Response
# 1                                     Full time Employee
# 2                                     Full time Employee
# 3                                     Full time Employee
# 4                                     Full time Employee
# ...                                                  ...
# 17109                                 Full time Employee
# 17110                                 Full time Employee
# 17111                                 Full time Employee
# 17112                                 Full time Employee
# 17113                                 Full time Employee
#
#       Question + Subquestion    Answer Question
# 0                 Question 1  Response      NaN
# 1                 Question 1       NaN      NaN
# 2                 Question 1  Answer 4      NaN
# 3                 Question 1  Answer 5      NaN
# 4                 Question 1  Answer 1      NaN
# ...                      ...       ...      ...
# 17109            Unnamed: 99  Answer 8      NaN
# 17110            Unnamed: 99  Answer 6      NaN
# 17111            Unnamed: 99       NaN      NaN
# 17112            Unnamed: 99       NaN      NaN
# 17113            Unnamed: 99       NaN      NaN
#
# [17114 rows x 11 columns]

# %%
respondents = dataset_merged[dataset_merged["Answer"].notna()]
respondents = respondents.groupby("Question")["Respondent ID"].nunique().reset_index()
respondents.rename(columns={"Respondent ID":"Respondents"}, inplace=True)
respondents
# Out:
# Empty DataFrame
# Columns: [Question, Respondents]
# Index: []

# %%
dataset_merged_two = pd.merge(left=dataset_merged, right=respondents, how="left", left_on="Question", right_on="Question")
print("Original Data", len(dataset_merged))
print("Merged Data", len(dataset_merged_two))
dataset_merged_two
# Out:
# Original Data 17114
# Merged Data 17114
#        Respondent ID Identify which division you work in.  \
# 0                NaN                             Response
# 1       5.379192e+09                       Infrastructure
# 2       2.658723e+09                              Finance
# 3       4.044163e+09                       Infrastructure
# 4       5.535866e+09                       Infrastructure
# ...              ...                                  ...
# 17109   7.940065e+09                       Infrastructure
# 17110   5.157706e+09                              Finance
# 17111   9.920756e+09                      Port Operations
# 17112   6.638341e+09                       Infrastructure
# 17113   8.114622e+09               Information Technology
#
#                    Unnamed: 8  \
# 0      Other (please specify)
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 17109                     NaN
# 17110                     NaN
# 17111                     NaN
# 17112                     NaN
# 17113                     NaN
#
#       Which of the following best describes your position level?  \
# 0                                               Response
# 1                                                  Staff
# 2                                                  Staff
# 3                                        Department Lead
# 4                                                Manager
# ...                                                  ...
# 17109                                    Department Lead
# 17110                                              Staff
# 17111                                              Staff
# 17112                                            Manager
# 17113                                              Staff
#
#           Which generation are you apart of?  \
# 0                                   Response
# 1      Generation X (born between 1965-1980)
# 2                                        NaN
# 3      Generation X (born between 1965-1980)
# 4        Millennial (born between 1981-2000)
# ...                                      ...
# 17109   Baby Boomer (born between 1946-1964)
# 17110    Millennial (born between 1981-2000)
# 17111    Millennial (born between 1981-2000)
# 17112    Millennial (born between 1981-2000)
# 17113                   Prefer not to answer
#
#       Please select the gender in which you identify.  \
# 0                                            Response
# 1                                                Male
# 2                                                 NaN
# 3                                                Male
# 4                                          Non-Binary
# ...                                               ...
# 17109                                            Male
# 17110                                          Female
# 17111                                          Female
# 17112                                          Female
# 17113                                            Male
#
#       Which duration range best aligns with your tenure at your company?  \
# 0                                               Response
# 1                                              0-2 years
# 2                                              10+ years
# 3                                              3-5 years
# 4                                             5-10 years
# ...                                                  ...
# 17109                                          10+ years
# 17110                                         5-10 years
# 17111                                          3-5 years
# 17112                                          3-5 years
# 17113                                         5-10 years
#
#       Which of the following best describes your employment type?  \
# 0                                               Response
# 1                                     Full time Employee
# 2                                     Full time Employee
# 3                                     Full time Employee
# 4                                     Full time Employee
# ...                                                  ...
# 17109                                 Full time Employee
# 17110                                 Full time Employee
# 17111                                 Full time Employee
# 17112                                 Full time Employee
# 17113                                 Full time Employee
#
#       Question + Subquestion    Answer Question  Respondents
# 0                 Question 1  Response      NaN          NaN
# 1                 Question 1       NaN      NaN          NaN
# 2                 Question 1  Answer 4      NaN          NaN
# 3                 Question 1  Answer 5      NaN          NaN
# 4                 Question 1  Answer 1      NaN          NaN
# ...                      ...       ...      ...          ...
# 17109            Unnamed: 99  Answer 8      NaN          NaN
# 17110            Unnamed: 99  Answer 6      NaN          NaN
# 17111            Unnamed: 99       NaN      NaN          NaN
# 17112            Unnamed: 99       NaN      NaN          NaN
# 17113            Unnamed: 99       NaN      NaN          NaN
#
# [17114 rows x 12 columns]

# %%
same_answer = dataset_merged # [dataset_merged["Answer"].notna()]
same_answer = same_answer.groupby(["Question + Subquestion", "Answer"])["Respondent ID"].nunique().reset_index()
same_answer.rename(columns={"Respondent ID":"Same Answer"}, inplace=True)
same_answer
# Out:
#     Question + Subquestion      Answer  Same Answer
# 0               Question 1    Answer 1           14
# 1               Question 1    Answer 2           10
# 2               Question 1    Answer 3           13
# 3               Question 1    Answer 4           17
# 4               Question 1    Answer 5           22
# ..                     ...         ...          ...
# 769            Unnamed: 99    Answer 5           18
# 770            Unnamed: 99    Answer 6           20
# 771            Unnamed: 99    Answer 7           15
# 772            Unnamed: 99    Answer 8           14
# 773            Unnamed: 99  Response 3            0
#
# [774 rows x 3 columns]

# %%
dataset_merged_three = pd.merge(left=dataset_merged_two, right=same_answer, how="left", left_on=["Question + Subquestion", "Answer"], right_on=["Question + Subquestion", "Answer"])
dataset_merged_three["Same Answer"].fillna(0, inplace=True)
print("Original Data", len(dataset_merged_two))
print("Merged Data", len(dataset_merged_three))
dataset_merged_three
# Out:
# Original Data 17114
# Merged Data 17114
#        Respondent ID Identify which division you work in.  \
# 0                NaN                             Response
# 1       5.379192e+09                       Infrastructure
# 2       2.658723e+09                              Finance
# 3       4.044163e+09                       Infrastructure
# 4       5.535866e+09                       Infrastructure
# ...              ...                                  ...
# 17109   7.940065e+09                       Infrastructure
# 17110   5.157706e+09                              Finance
# 17111   9.920756e+09                      Port Operations
# 17112   6.638341e+09                       Infrastructure
# 17113   8.114622e+09               Information Technology
#
#                    Unnamed: 8  \
# 0      Other (please specify)
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 17109                     NaN
# 17110                     NaN
# 17111                     NaN
# 17112                     NaN
# 17113                     NaN
#
#       Which of the following best describes your position level?  \
# 0                                               Response
# 1                                                  Staff
# 2                                                  Staff
# 3                                        Department Lead
# 4                                                Manager
# ...                                                  ...
# 17109                                    Department Lead
# 17110                                              Staff
# 17111                                              Staff
# 17112                                            Manager
# 17113                                              Staff
#
#           Which generation are you apart of?  \
# 0                                   Response
# 1      Generation X (born between 1965-1980)
# 2                                        NaN
# 3      Generation X (born between 1965-1980)
# 4        Millennial (born between 1981-2000)
# ...                                      ...
# 17109   Baby Boomer (born between 1946-1964)
# 17110    Millennial (born between 1981-2000)
# 17111    Millennial (born between 1981-2000)
# 17112    Millennial (born between 1981-2000)
# 17113                   Prefer not to answer
#
#       Please select the gender in which you identify.  \
# 0                                            Response
# 1                                                Male
# 2                                                 NaN
# 3                                                Male
# 4                                          Non-Binary
# ...                                               ...
# 17109                                            Male
# 17110                                          Female
# 17111                                          Female
# 17112                                          Female
# 17113                                            Male
#
#       Which duration range best aligns with your tenure at your company?  \
# 0                                               Response
# 1                                              0-2 years
# 2                                              10+ years
# 3                                              3-5 years
# 4                                             5-10 years
# ...                                                  ...
# 17109                                          10+ years
# 17110                                         5-10 years
# 17111                                          3-5 years
# 17112                                          3-5 years
# 17113                                         5-10 years
#
#       Which of the following best describes your employment type?  \
# 0                                               Response
# 1                                     Full time Employee
# 2                                     Full time Employee
# 3                                     Full time Employee
# 4                                     Full time Employee
# ...                                                  ...
# 17109                                 Full time Employee
# 17110                                 Full time Employee
# 17111                                 Full time Employee
# 17112                                 Full time Employee
# 17113                                 Full time Employee
#
#       Question + Subquestion    Answer Question  Respondents  Same Answer
# 0                 Question 1  Response      NaN          NaN          0.0
# 1                 Question 1       NaN      NaN          NaN          0.0
# 2                 Question 1  Answer 4      NaN          NaN         17.0
# 3                 Question 1  Answer 5      NaN          NaN         22.0
# 4                 Question 1  Answer 1      NaN          NaN         14.0
# ...                      ...       ...      ...          ...          ...
# 17109            Unnamed: 99  Answer 8      NaN          NaN         14.0
# 17110            Unnamed: 99  Answer 6      NaN          NaN         20.0
# 17111            Unnamed: 99       NaN      NaN          NaN          0.0
# 17112            Unnamed: 99       NaN      NaN          NaN          0.0
# 17113            Unnamed: 99       NaN      NaN          NaN          0.0
#
# [17114 rows x 13 columns]

# %%
output = dataset_merged_three.copy()
output.rename(columns={"Identify which division you work in. - Response":"Division Primary", "Identify which division you work in. - Other (please specify)":"Division Secondary", "Which of the following best describes your position level? - Response":"Position", "Which generation are you apart of? - Response":"Generation", "Please select the gender in which you identify. - Response":"Gender", "Which duration range best aligns with your tenure at your company? - Response":"Tenure", "Which of the following best describes your employment type? - Response":"Employment Type"}, inplace=True)
output
# Out:
#        Respondent ID Identify which division you work in.  \
# 0                NaN                             Response
# 1       5.379192e+09                       Infrastructure
# 2       2.658723e+09                              Finance
# 3       4.044163e+09                       Infrastructure
# 4       5.535866e+09                       Infrastructure
# ...              ...                                  ...
# 17109   7.940065e+09                       Infrastructure
# 17110   5.157706e+09                              Finance
# 17111   9.920756e+09                      Port Operations
# 17112   6.638341e+09                       Infrastructure
# 17113   8.114622e+09               Information Technology
#
#                    Unnamed: 8  \
# 0      Other (please specify)
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 17109                     NaN
# 17110                     NaN
# 17111                     NaN
# 17112                     NaN
# 17113                     NaN
#
#       Which of the following best describes your position level?  \
# 0                                               Response
# 1                                                  Staff
# 2                                                  Staff
# 3                                        Department Lead
# 4                                                Manager
# ...                                                  ...
# 17109                                    Department Lead
# 17110                                              Staff
# 17111                                              Staff
# 17112                                            Manager
# 17113                                              Staff
#
#           Which generation are you apart of?  \
# 0                                   Response
# 1      Generation X (born between 1965-1980)
# 2                                        NaN
# 3      Generation X (born between 1965-1980)
# 4        Millennial (born between 1981-2000)
# ...                                      ...
# 17109   Baby Boomer (born between 1946-1964)
# 17110    Millennial (born between 1981-2000)
# 17111    Millennial (born between 1981-2000)
# 17112    Millennial (born between 1981-2000)
# 17113                   Prefer not to answer
#
#       Please select the gender in which you identify.  \
# 0                                            Response
# 1                                                Male
# 2                                                 NaN
# 3                                                Male
# 4                                          Non-Binary
# ...                                               ...
# 17109                                            Male
# 17110                                          Female
# 17111                                          Female
# 17112                                          Female
# 17113                                            Male
#
#       Which duration range best aligns with your tenure at your company?  \
# 0                                               Response
# 1                                              0-2 years
# 2                                              10+ years
# 3                                              3-5 years
# 4                                             5-10 years
# ...                                                  ...
# 17109                                          10+ years
# 17110                                         5-10 years
# 17111                                          3-5 years
# 17112                                          3-5 years
# 17113                                         5-10 years
#
#       Which of the following best describes your employment type?  \
# 0                                               Response
# 1                                     Full time Employee
# 2                                     Full time Employee
# 3                                     Full time Employee
# 4                                     Full time Employee
# ...                                                  ...
# 17109                                 Full time Employee
# 17110                                 Full time Employee
# 17111                                 Full time Employee
# 17112                                 Full time Employee
# 17113                                 Full time Employee
#
#       Question + Subquestion    Answer Question  Respondents  Same Answer
# 0                 Question 1  Response      NaN          NaN          0.0
# 1                 Question 1       NaN      NaN          NaN          0.0
# 2                 Question 1  Answer 4      NaN          NaN         17.0
# 3                 Question 1  Answer 5      NaN          NaN         22.0
# 4                 Question 1  Answer 1      NaN          NaN         14.0
# ...                      ...       ...      ...          ...          ...
# 17109            Unnamed: 99  Answer 8      NaN          NaN         14.0
# 17110            Unnamed: 99  Answer 6      NaN          NaN         20.0
# 17111            Unnamed: 99       NaN      NaN          NaN          0.0
# 17112            Unnamed: 99       NaN      NaN          NaN          0.0
# 17113            Unnamed: 99       NaN      NaN          NaN          0.0
#
# [17114 rows x 13 columns]

# %%
output.to_csv(pwd + "/Final_Output.csv", index=False)
